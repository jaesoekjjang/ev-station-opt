# %%
import pandas as pd
import os

# %%
DF1_FILENAME = '20220925_아파트정보목록.xls'
DF1_FILEPATH = os.path.join(os.path.dirname(os.getcwd()),'data','dataset',DF1_FILENAME)
df = pd.read_excel(DF1_FILEPATH)
df
# Out:
#        구     동  구분           단지명  세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택   85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오  363                20220628
# 2    수지구   신봉동  분양     힐스테이트 광교산  789                20220429
# 3    수지구   동천동  분양   한화 포레나 수지동천  293                20220221
# 4    기흥구   언남동  분양      힐스테이트 구성  699     (20210731~20230730)
# ..   ...   ...  ..           ...  ...                     ...
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양         신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양         삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트   51              1992.04.11
#
#                                     도로명주소
# 0                                     수지구
# 1                          수지구 신봉3로7번길 31
# 2                        신봉동 신봉도시개발구역 7블럭
# 3                     수지구 동천동 349-10번지 일원
# ...

# %%
address= df['도로명주소']
address
# Out:
# 0                                       수지구
# 1                            수지구 신봉3로7번길 31
# 2                          신봉동 신봉도시개발구역 7블럭
# 3                       수지구 동천동 349-10번지 일원
# 4                              기흥구 용인향교로 29
#                        ...
# 578          처인구 중부대로 1348 (김량장동, 삼환나우빌아파트)
# 579         처인구 중부대로1388번길 12 (김량장동, 신우아파트)
# 580        처인구 중부대로1388번길 6-4 (김량장동, 삼환아파트)
# 581    처인구 중부대로1424번길 5-6 (김량장동, 청광가든빌리지1차)
# 582        처인구 금령로40번길 13 (김량장동, 조양유통상가아파트)
# Name: 도로명주소, Length: 583, dtype: object

# %%
a_1 = df.query('도로명주소.str.contains("경기도|용인시")', engine='python')
a_1
# Out:
#       구    동  구분             단지명  세대수     사용검사일  \
# 68  처인구  역북동  임대    역북2단지 우남퍼스트빌  505  20161024
# 69  처인구  역북동  임대    역북1단지 우남퍼스트빌  409  20161024
# 70  기흥구  동백동  분양      하우스디 동백테라스   90  20170102
# 71  기흥구   중동  분양      신동백 동도센트리움  254  20161214
# 72  기흥구  마북동  분양  구성역 효성해링턴 플레이스  296  20161123
# 73  기흥구  서천동  분양        힐스테이트 서천  754  20160929
# 74  처인구   천리  분양       용인 에이스카운티  430  20160808
# 75  기흥구  보정동  분양     죽전 1차 힐데스하임   40  20160729
#
#                              도로명주소
# 68            용인시 처인구 낙은로 59 (역북동)
# 69            용인시 처인구 낙은로 60 (역북동)
# 70  경기도 용인시 기흥구 동백7로107번길 10 (동백동)
# 71        경기도 용인시 기흥구 언동로 201 (중동)
# 72   경기도 용인시 기흥구 구성로 53번길 20 (마북동)
# 73           용인시 기흥구 서천동로 22 (서천동)
# 74        경기도 용인시 처인구 이동읍 백옥대로 737
# 75        경기도 용인시 기흥구 신촌로 93 (보정동)

# %%
a_2 = df.query('도로명주소.str.contains("경기도|용인시")', engine='python').index
a_2
# Out:
# Int64Index([68, 69, 70, 71, 72, 73, 74, 75], dtype='int64')

# %%
df_1=df.drop(a_2)
df_1
# Out:
#        구     동  구분           단지명  세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택   85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오  363                20220628
# 2    수지구   신봉동  분양     힐스테이트 광교산  789                20220429
# 3    수지구   동천동  분양   한화 포레나 수지동천  293                20220221
# 4    기흥구   언남동  분양      힐스테이트 구성  699     (20210731~20230730)
# ..   ...   ...  ..           ...  ...                     ...
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양         신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양         삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트   51              1992.04.11
#
#                                     도로명주소
# 0                                     수지구
# 1                          수지구 신봉3로7번길 31
# 2                        신봉동 신봉도시개발구역 7블럭
# 3                     수지구 동천동 349-10번지 일원
# ...

# %%
df_1[66:]
# Out:
#        구     동  구분          단지명  세대수                   사용검사일  \
# 66   기흥구   마북동  분양   구성 지음재 아파트   80                20170524
# 67   수지구  상현2동  분양    수지 동도센트리움  168                20170331
# 76   수지구   상현동  분양   용인 수지 휴엔하임  112                20160411
# 77   기흥구   서천동  분양    서천2차IPARK  289                20160226
# 78   수지구  풍덕천동  분양  래미안수지 이스트파크  845             2015.10.29.
# ..   ...   ...  ..          ...  ...                     ...
# 578  처인구  김량장동  분양  아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양        신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양        삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양    청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양    조양유통상가아파트   51              1992.04.11
#
#                                     도로명주소
# 66                          기흥구 구성로53번길 8
# 67                            수지구 이현로 125
# 76          수지구 상현로 152 (상현동, 수지 휴엔하임아파트)
# 77    기흥구 서천동로21번길 11-22 (서천동, 서천2차 아이파크)
# ...

# %%
df['도로명주소'] = '경기도 용인시 ' + df_1['도로명주소'].astype(str)
df
# Out:
#        구     동  구분           단지명  세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택   85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오  363                20220628
# 2    수지구   신봉동  분양     힐스테이트 광교산  789                20220429
# 3    수지구   동천동  분양   한화 포레나 수지동천  293                20220221
# 4    기흥구   언남동  분양      힐스테이트 구성  699     (20210731~20230730)
# ..   ...   ...  ..           ...  ...                     ...
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양         신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양         삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트   51              1992.04.11
#
#                                             도로명주소
# 0                                     경기도 용인시 수지구
# 1                          경기도 용인시 수지구 신봉3로7번길 31
# 2                        경기도 용인시 신봉동 신봉도시개발구역 7블럭
# ...

# %%
df[68:]
# Out:
#        구     동  구분             단지명  세대수                   사용검사일  \
# 68   처인구   역북동  임대    역북2단지 우남퍼스트빌  505                20161024
# 69   처인구   역북동  임대    역북1단지 우남퍼스트빌  409                20161024
# 70   기흥구   동백동  분양      하우스디 동백테라스   90                20170102
# 71   기흥구    중동  분양      신동백 동도센트리움  254                20161214
# 72   기흥구   마북동  분양  구성역 효성해링턴 플레이스  296                20161123
# ..   ...   ...  ..             ...  ...                     ...
# 578  처인구  김량장동  분양     아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양           신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양           삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양       청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양       조양유통상가아파트   51              1992.04.11
#
#                                             도로명주소
# 68                                            NaN
# 69                                            NaN
# ...

# %%
df_2=df.dropna()
df_2
# Out:
#        구     동  구분           단지명  세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택   85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오  363                20220628
# 2    수지구   신봉동  분양     힐스테이트 광교산  789                20220429
# 3    수지구   동천동  분양   한화 포레나 수지동천  293                20220221
# 4    기흥구   언남동  분양      힐스테이트 구성  699     (20210731~20230730)
# ..   ...   ...  ..           ...  ...                     ...
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양         신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양         삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트   51              1992.04.11
#
#                                             도로명주소
# 0                                     경기도 용인시 수지구
# 1                          경기도 용인시 수지구 신봉3로7번길 31
# 2                        경기도 용인시 신봉동 신봉도시개발구역 7블럭
# ...

# %%
new_df = pd.concat([df_2,a_1])
new_df
# Out:
#       구    동  구분             단지명  세대수                사용검사일  \
# 0   수지구  죽전동  임대    용인 죽전 경기행복주택   85             20220826
# 1   수지구  신봉동  분양      수지스카이뷰푸르지오  363             20220628
# 2   수지구  신봉동  분양       힐스테이트 광교산  789             20220429
# 3   수지구  동천동  분양     한화 포레나 수지동천  293             20220221
# 4   기흥구  언남동  분양        힐스테이트 구성  699  (20210731~20230730)
# ..  ...  ...  ..             ...  ...                  ...
# 71  기흥구   중동  분양      신동백 동도센트리움  254             20161214
# 72  기흥구  마북동  분양  구성역 효성해링턴 플레이스  296             20161123
# 73  기흥구  서천동  분양        힐스테이트 서천  754             20160929
# 74  처인구   천리  분양       용인 에이스카운티  430             20160808
# 75  기흥구  보정동  분양     죽전 1차 힐데스하임   40             20160729
#
#                             도로명주소
# 0                     경기도 용인시 수지구
# 1          경기도 용인시 수지구 신봉3로7번길 31
# 2        경기도 용인시 신봉동 신봉도시개발구역 7블럭
# 3     경기도 용인시 수지구 동천동 349-10번지 일원
# 4            경기도 용인시 기흥구 용인향교로 29
# ..                            ...
# ...

# %%
import re
a1=new_df['도로명주소'].apply(lambda x : re.sub(r' \([^)]*\)', '', x))
new_df['도로명주소']=a1
new_df
# Out:
#       구    동  구분             단지명  세대수                사용검사일  \
# 0   수지구  죽전동  임대    용인 죽전 경기행복주택   85             20220826
# 1   수지구  신봉동  분양      수지스카이뷰푸르지오  363             20220628
# 2   수지구  신봉동  분양       힐스테이트 광교산  789             20220429
# 3   수지구  동천동  분양     한화 포레나 수지동천  293             20220221
# 4   기흥구  언남동  분양        힐스테이트 구성  699  (20210731~20230730)
# ..  ...  ...  ..             ...  ...                  ...
# 71  기흥구   중동  분양      신동백 동도센트리움  254             20161214
# 72  기흥구  마북동  분양  구성역 효성해링턴 플레이스  296             20161123
# 73  기흥구  서천동  분양        힐스테이트 서천  754             20160929
# 74  처인구   천리  분양       용인 에이스카운티  430             20160808
# 75  기흥구  보정동  분양     죽전 1차 힐데스하임   40             20160729
#
#                           도로명주소
# 0                   경기도 용인시 수지구
# 1        경기도 용인시 수지구 신봉3로7번길 31
# 2      경기도 용인시 신봉동 신봉도시개발구역 7블럭
# 3   경기도 용인시 수지구 동천동 349-10번지 일원
# 4          경기도 용인시 기흥구 용인향교로 29
# ..                          ...
# ...

# %%
address = new_df['도로명주소']
address
# Out:
# 0                     경기도 용인시 수지구
# 1          경기도 용인시 수지구 신봉3로7번길 31
# 2        경기도 용인시 신봉동 신봉도시개발구역 7블럭
# 3     경기도 용인시 수지구 동천동 349-10번지 일원
# 4            경기도 용인시 기흥구 용인향교로 29
#                  ...
# 71            경기도 용인시 기흥구 언동로 201
# 72        경기도 용인시 기흥구 구성로 53번길 20
# 73                용인시 기흥구 서천동로 22
# 74       경기도 용인시 처인구 이동읍 백옥대로 737
# 75             경기도 용인시 기흥구 신촌로 93
# Name: 도로명주소, Length: 583, dtype: object

# %%
pip install geopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
####### 도로명주소 위도 경도 값으로 바꿔주기 ########
from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

# 위도, 경도 반환하는 함수
def geocoding(address):
    try:
        geo = geo_local.geocode(address)
        x_y = [geo.latitude, geo.longitude]
        return x_y

    except:
        return [0,0]

# %%
latitude = []
longitude =[]

for i in address:
    (a, b) = geocoding(i)
    latitude.append (a)
    longitude.append(b)

# %%
#####Dataframe만들기######
address_df = pd.DataFrame({'구':df['구'],'동':df['동'],'구분':df['구분'],'단지명':df['단지명'],
                           '세대수':df['세대수'],'사용검사일':df['사용검사일'],
                           '주소':address,'위도':latitude,'경도':longitude})
address_df
# Out:
#        구     동  구분           단지명  세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택   85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오  363                20220628
# 2    수지구   신봉동  분양     힐스테이트 광교산  789                20220429
# 3    수지구   동천동  분양   한화 포레나 수지동천  293                20220221
# 4    기흥구   언남동  분양      힐스테이트 구성  699     (20210731~20230730)
# ..   ...   ...  ..           ...  ...                     ...
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌  458  2008.08.08(2007.12.31)
# 579  처인구  김량장동  분양         신우아파트  178              1999.10.29
# 580  처인구  김량장동  분양         삼환아파트  180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차   21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트   51              1992.04.11
#
#                               주소         위도          경도
# 0                    경기도 용인시 수지구  37.322293  127.097211
# 1         경기도 용인시 수지구 신봉3로7번길 31  37.326714  127.069025
# ...

# %%
sum(address_df['위도']==0)
# Out:
# 94

# %%
address_dfN = address_df[address_df['위도']==0].copy()
address_dfN['주소'] = address_dfN['주소'].apply(lambda x: ' '.join(x.split(' ')[:4]))
address_dfN
# Out:
#        구        동  구분              단지명   세대수       사용검사일  \
# 2    수지구      신봉동  분양        힐스테이트 광교산   789    20220429
# 3    수지구      동천동  분양      한화 포레나 수지동천   293    20220221
# 15   처인구  남사면 아곡리  분양  e편한 세상 용인 파크카운티    75    20190628
# 18   기흥구      보라동  분양      보라효성해링턴플레이스   970    20190529
# 23   기흥구      영덕동  분양     기흥 효성해링턴플레이스  1679    20190329
# ..   ...      ...  ..              ...   ...         ...
# 569  처인구      마평동  분양               목련    25  1990.11.06
# 573  처인구      고림동  분양            이삭아파트   300  1998.12.24
# 574  처인구      고림동  분양           성림아트맨션    45  1990.02.23
# 577  처인구     김량장동  분양      능안마을 그린힐아파트    86  2004.11.01
# 579  처인구     김량장동  분양            신우아파트   178  1999.10.29
#
#                          주소   위도   경도
# 2      경기도 용인시 신봉동 신봉도시개발구역  0.0  0.0
# 3           경기도 용인시 수지구 동천동  0.0  0.0
# 15          경기도 용인시 처인구 남사면  0.0  0.0
# 18      경기도 용인시 기흥구 사은로84번길  0.0  0.0
# 23   경기도 용인시 기흥구 영덕대로2077번길  0.0  0.0
# ..                      ...  ...  ...
# ...

# %%
address_df.drop(address_df[address_df['위도']==0].index, axis=0, inplace=True)

# %%
address_df
# Out:
#        구     동  구분           단지명   세대수                   사용검사일  \
# 0    수지구   죽전동  임대  용인 죽전 경기행복주택    85                20220826
# 1    수지구   신봉동  분양    수지스카이뷰푸르지오   363                20220628
# 4    기흥구   언남동  분양      힐스테이트 구성   699     (20210731~20230730)
# 5    기흥구   동백동  분양  신동백 두산위브더제니스  1187                20210630
# 6    수지구   죽전동  분양       죽전역 솔하임   234                20210309
# ..   ...   ...  ..           ...   ...                     ...
# 576  처인구  김량장동  분양     청광가든빌리지2차    24              1989.01.11
# 578  처인구  김량장동  분양   아리현마을 삼환나우빌   458  2008.08.08(2007.12.31)
# 580  처인구  김량장동  분양         삼환아파트   180              1999.11.30
# 581  처인구  김량장동  분양     청광가든빌리지1차    21              1988.06.09
# 582  처인구  김량장동  분양     조양유통상가아파트    51              1992.04.11
#
#                              주소         위도          경도
# 0                   경기도 용인시 수지구  37.322293  127.097211
# 1        경기도 용인시 수지구 신봉3로7번길 31  37.326714  127.069025
# ...

# %%
address = address_dfN['주소']
address
# Out:
# 2        경기도 용인시 신봉동 신봉도시개발구역
# 3             경기도 용인시 수지구 동천동
# 15            경기도 용인시 처인구 남사면
# 18        경기도 용인시 기흥구 사은로84번길
# 23     경기도 용인시 기흥구 영덕대로2077번길
#                 ...
# 569    경기도 용인시 처인구 중부대로1504번길
# 573     경기도 용인시 처인구 경안천로256번길
# 574      경기도 용인시 처인구 고림로110번길
# 577      경기도 용인시 처인구 금학로349번길
# 579    경기도 용인시 처인구 중부대로1388번길
# Name: 주소, Length: 94, dtype: object

# %%
'''''
for i in range(len(address)):
    a = address_2[i].split(' ')
    address_2[i] = " ".join(a[0:5])
print(address_2)
'''''
# Out:
# '\'\'\nfor i in range(len(address)):\n    a = address_2[i].split(\' \')\n    address_2[i] = " ".join(a[0:5])\nprint(address_2)\n'

# %%
latitude = []
longitude =[]

for i in address:
    (a, b) = geocoding(i)
    latitude.append (a)
    longitude.append(b)

# %%
#####Dataframe만들기######
address_df3 = pd.DataFrame({'구':address_dfN['구'],'동':address_dfN['동'],'구분':address_dfN['구분'],'단지명':address_dfN['단지명'],
                           '세대수':address_dfN['세대수'],'사용검사일':address_dfN['사용검사일'],
                           '주소':address,'위도':latitude,'경도':longitude})
address_df3
# Out:
#        구        동  구분              단지명   세대수       사용검사일  \
# 2    수지구      신봉동  분양        힐스테이트 광교산   789    20220429
# 3    수지구      동천동  분양      한화 포레나 수지동천   293    20220221
# 15   처인구  남사면 아곡리  분양  e편한 세상 용인 파크카운티    75    20190628
# 18   기흥구      보라동  분양      보라효성해링턴플레이스   970    20190529
# 23   기흥구      영덕동  분양     기흥 효성해링턴플레이스  1679    20190329
# ..   ...      ...  ..              ...   ...         ...
# 569  처인구      마평동  분양               목련    25  1990.11.06
# 573  처인구      고림동  분양            이삭아파트   300  1998.12.24
# 574  처인구      고림동  분양           성림아트맨션    45  1990.02.23
# 577  처인구     김량장동  분양      능안마을 그린힐아파트    86  2004.11.01
# 579  처인구     김량장동  분양            신우아파트   178  1999.10.29
#
#                          주소         위도          경도
# 2      경기도 용인시 신봉동 신봉도시개발구역   0.000000    0.000000
# 3           경기도 용인시 수지구 동천동  37.341837  127.099298
# 15          경기도 용인시 처인구 남사면   0.000000    0.000000
# 18      경기도 용인시 기흥구 사은로84번길   0.000000    0.000000
# ...

# %%
fin_df = pd.concat([address_df,address_df3])
fin_df.reset_index(inplace=True)

# %%
fin_df
# Out:
#      index    구     동  구분           단지명   세대수                사용검사일  \
# 0        0  수지구   죽전동  임대  용인 죽전 경기행복주택    85             20220826
# 1        1  수지구   신봉동  분양    수지스카이뷰푸르지오   363             20220628
# 2        4  기흥구   언남동  분양      힐스테이트 구성   699  (20210731~20230730)
# 3        5  기흥구   동백동  분양  신동백 두산위브더제니스  1187             20210630
# 4        6  수지구   죽전동  분양       죽전역 솔하임   234             20210309
# ..     ...  ...   ...  ..           ...   ...                  ...
# 578    569  처인구   마평동  분양            목련    25           1990.11.06
# 579    573  처인구   고림동  분양         이삭아파트   300           1998.12.24
# 580    574  처인구   고림동  분양        성림아트맨션    45           1990.02.23
# 581    577  처인구  김량장동  분양   능안마을 그린힐아파트    86           2004.11.01
# 582    579  처인구  김량장동  분양         신우아파트   178           1999.10.29
#
#                          주소         위도          경도
# 0               경기도 용인시 수지구  37.322293  127.097211
# 1    경기도 용인시 수지구 신봉3로7번길 31  37.326714  127.069025
# ...

# %%
fin_df.drop(fin_df[fin_df['위도']==0].index, axis=0, inplace=True)

# %%
fin_df
# Out:
#      index    구        동  구분           단지명   세대수                사용검사일  \
# 0        0  수지구      죽전동  임대  용인 죽전 경기행복주택    85             20220826
# 1        1  수지구      신봉동  분양    수지스카이뷰푸르지오   363             20220628
# 2        4  기흥구      언남동  분양      힐스테이트 구성   699  (20210731~20230730)
# 3        5  기흥구      동백동  분양  신동백 두산위브더제니스  1187             20210630
# 4        6  수지구      죽전동  분양       죽전역 솔하임   234             20210309
# ..     ...  ...      ...  ..           ...   ...                  ...
# 576    563  처인구  모현읍 왕산리  분양     풍산햇빛마을아파트   330           2000.03.24
# 577    568  처인구      마평동  분양     마평 라이프아파트   290           1993.06.11
# 579    573  처인구      고림동  분양         이삭아파트   300           1998.12.24
# 580    574  처인구      고림동  분양        성림아트맨션    45           1990.02.23
# 582    579  처인구     김량장동  분양         신우아파트   178           1999.10.29
#
#                          주소         위도          경도
# 0               경기도 용인시 수지구  37.322293  127.097211
# ...

# %%
fin_df.to_csv( '../data/dataset/20220925_아파트정보목록_위경도 추가.csv')
